# %%
import pandas as pd
import psycopg2
import os
from dotenv import load_dotenv
from tqdm import tqdm
# Out:
# /var/folders/fp/jvqr90jn2gsf_6qw7t0xk7br0000gn/T/ipykernel_29046/910991213.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
load_dotenv()
DATABASE_URL = os.environ.get('DATABASE_URL')
assert DATABASE_URL is not None, 'Missing DATABASE_URL environment variable to connect to the database'
# connect to db
conn = psycopg2.connect(DATABASE_URL)

# Open a cursor to perform database operations
cur = conn.cursor()
cur.execute(
    '''CREATE TABLE IF NOT EXISTS genes (id VARCHAR, 
                                        description VARCHAR,
                                        gene_symbol VARCHAR, 
                                        synonyms VARCHAR )''')

# %%
genes_info = pd.read_table('Homo_sapiens.gene_info')
genes_info
# Out:
#         #tax_id   GeneID    Symbol LocusTag                   Synonyms  \
# 0          9606        1      A1BG        -       A1B|ABG|GAB|HYST2477
# 1          9606        2       A2M        -  A2MD|CPAMD5|FWP007|S863-7
# 2          9606        3     A2MP1        -                       A2MP
# 3          9606        9      NAT1        -       AAC1|MNAT|NAT-1|NATI
# 4          9606       10      NAT2        -            AAC2|NAT-2|PNAT
# ...         ...      ...       ...      ...                        ...
# 193454   741158  8923215      trnD        -                          -
# 193455   741158  8923216      trnP        -                          -
# 193456   741158  8923217      trnA        -                          -
# 193457   741158  8923218      COX1        -                          -
# 193458   741158  8923219  16S rRNA        -                          -
#
#                                                   dbXrefs chromosome  \
# 0       MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410...         19
# 1       MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899...         12
# 2       HGNC:HGNC:8|Ensembl:ENSG00000291190|AllianceGe...         12
# 3       MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171...          8
# 4       MIM:612182|HGNC:HGNC:7646|Ensembl:ENSG00000156...          8
# ...                                                   ...        ...
# 193454                                                  -         MT
# 193455                                                  -         MT
# 193456                                                  -         MT
# 193457                                                  -         MT
# 193458                                                  -         MT
#
#        map_location                         description    type_of_gene  \
# 0          19q13.43              alpha-1-B glycoprotein  protein-coding
# 1          12p13.31               alpha-2-macroglobulin  protein-coding
# 2          12p13.31  alpha-2-macroglobulin pseudogene 1          pseudo
# 3              8p22               N-acetyltransferase 1  protein-coding
# 4              8p22               N-acetyltransferase 2  protein-coding
# ...             ...                                 ...             ...
# 193454            -                            tRNA-Asp            tRNA
# 193455            -                            tRNA-Pro            tRNA
# 193456            -                            tRNA-Ala            tRNA
# 193457            -      cytochrome c oxidase subunit I  protein-coding
# 193458            -                              l-rRNA            rRNA
#
#        Symbol_from_nomenclature_authority  \
# 0                                    A1BG
# 1                                     A2M
# 2                                   A2MP1
# 3                                    NAT1
# 4                                    NAT2
# ...                                   ...
# 193454                                  -
# 193455                                  -
# 193456                                  -
# 193457                                  -
# 193458                                  -
#
#        Full_name_from_nomenclature_authority Nomenclature_status  \
# 0                     alpha-1-B glycoprotein                   O
# 1                      alpha-2-macroglobulin                   O
# 2         alpha-2-macroglobulin pseudogene 1                   O
# 3                      N-acetyltransferase 1                   O
# 4                      N-acetyltransferase 2                   O
# ...                                      ...                 ...
# 193454                                     -                   -
# 193455                                     -                   -
# 193456                                     -                   -
# 193457                                     -                   -
# 193458                                     -                   -
#
#                                        Other_designations  Modification_date  \
# 0       alpha-1B-glycoprotein|HEL-S-163pA|epididymis s...           20231123
# 1       alpha-2-macroglobulin|C3 and PZP-like alpha-2-...           20240107
# 2                       pregnancy-zone protein pseudogene           20231010
# 3       arylamine N-acetyltransferase 1|N-acetyltransf...           20231123
# 4       arylamine N-acetyltransferase 2|N-acetyltransf...           20231225
# ...                                                   ...                ...
# 193454                                                  -           20200909
# 193455                                                  -           20200909
# 193456                                                  -           20200909
# 193457                     cytochrome c oxidase subunit I           20230818
# 193458                                                  -           20200909
#
#        Feature_type
# 0                 -
# 1                 -
# 2                 -
# 3                 -
# 4                 -
# ...             ...
# 193454            -
# 193455            -
# 193456            -
# 193457            -
# 193458            -
#
# [193459 rows x 16 columns]

# %%
for index, row in tqdm(genes_info.iterrows(), total=genes_info.shape[0]):
    cur.execute('''INSERT INTO genes (id, description, gene_symbol, synonyms) 
                    VALUES  (%s, %s, %s, %s);''', (row['GeneID'], row['description'], row['Symbol'], row['Synonyms']))

conn.commit()
cur.close()
conn.close()
# Out:
# 100%|██████████| 193459/193459 [00:11<00:00, 17522.17it/s]

# %%
cfde_genesets = pd.read_csv("CFDE Genesets.tsv", sep='\t')
cfde_genesets
# Out:
#             DCC                                           Library   \
# 0        Glygen                       Glygen Glycosylated Proteins
# 1          GTEx              GTEx Tissue-Specific Aging Signatures
# 2          GTEx               GTEx Tissue Gene Expression Profiles
# 3           IDG                                   IDG Drug Targets
# 4         KOMP2                             KOMP2 Mouse Phenotypes
# 5         LINCS  LINCS L1000 CMAP Chemical Pertubation Consensu...
# 6         LINCS  LINCS L1000 CMAP CRISPR Knockout Consensus Sig...
# 7       MoTrPAC            MoTrPAC Rat Endurance Exercise Training
# 8  Metabolomics          Metabolomics Gene-Metabolite Associations
#
#                                                 Link  Hypothesis template
# 0  https://cfde-drc.s3.amazonaws.com/GlyGen/XMT/2...                  NaN
# 1  https://cfde-drc.s3.amazonaws.com/GTEx/XMT/202...                  NaN
# 2  https://cfde-drc.s3.amazonaws.com/GTEx/XMT/202...                  NaN
# 3  https://cfde-drc.s3.amazonaws.com/IDG/XMT/2022...                  NaN
# 4  https://cfde-drc.s3.amazonaws.com/KOMP2/XMT/20...                  NaN
# 5  https://cfde-drc.s3.amazonaws.com/LINCS/XMT/20...                  NaN
# 6  https://cfde-drc.s3.amazonaws.com/LINCS/XMT/20...                  NaN
# 7  https://cfde-drc.s3.amazonaws.com/MoTrPAC/XMT/...                  NaN
# 8  https://cfde-drc.s3.amazonaws.com/MW/XMT/2022-...                  NaN

# %%
# read in all genes and convert to dataframe
ingested_genes = pd.read_sql("SELECT * from genes", conn)

# for each line, open with file link and populate database
for index, row in cfde_genesets.iterrows():
    import urllib.request
    with urllib.request.urlopen(row['Link']) as f:
        html = f.read().decode('utf-8') 
        for line in html.split('\n'):
            line_content = line.split('\t')
            geneset_name =  line_content[0]
            genes = line_content[1:]
            genes.remove('')
            for gene_symbol in genes: 
                gene_db_row = ingested_genes.loc[ingested_genes['gene_symbol'] == gene_symbol]
                if not gene_db_row.empty():
                    # do the relation 
                    print(gene_db_row['id'].values[0])
            # print(geneset_name)
            # print(genes)
        break
# Out:
# /var/folders/fp/jvqr90jn2gsf_6qw7t0xk7br0000gn/T/ipykernel_29046/916955059.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ingested_genes = pd.read_sql("SELECT * from genes", conn)
#        id gene_symbol       synonyms     description
# 919  1113        CHGA  CGA|PHE5|PHES  chromogranin A
# 1113
#            id gene_symbol              synonyms  \
# 27591  727897       MUC5B  MG1|MUC-5B|MUC5|MUC9
#
#                                   description
# 27591  mucin 5B, oligomeric mucus/gel-forming
# 727897
#         id gene_symbol   synonyms            description
# 5978  7450         VWF  F8VWF|VWD  von Willebrand factor
# 7450
#         id gene_symbol            synonyms  \
# 3599  4586      MUC5AC  MUC5|TBM|leB|mucin
#
#                                   description
# 3599  mucin 5AC, oligomeric mucus/gel-forming
# 4586
#          id gene_symbol                synonyms     description
# 7989  10216        PRG4  CACP|HAPO|JCAP|MSF|SZP  proteoglycan 4
# 10216
#         id gene_symbol                 synonyms                description
# 3466  4318        MMP9  CLG4B|GELB|MANDP2|MMP-9  matrix metallopeptidase 9
# 4318
#         id gene_symbol              synonyms    description
# 2876  3558         IL2  IL-2|TCGF|lymphokine  interleukin 2
# 3558
#         id gene_symbol                          synonyms  description
# 5608  7018          TF  HEL-S-71p|PRO1557|PRO2086|TFQTL1  transferrin
# 7018
#         id gene_symbol                                        synonyms  \
# 4579  5788       PTPRC  B220|CD45|CD45R|GP180|IMD105|L-CA|LCA|LY5|T200
#
#                                        description
# 4579  protein tyrosine phosphatase receptor type C
# 5788
#         id gene_symbol                         synonyms  \
# 6179  7784         ZP3  OOMD3|OZEMA3|ZP3A|ZP3B|ZPC|Zp-3
#
#                         description
# 6179  zona pellucida glycoprotein 3
# 7784
#         id gene_symbol      synonyms     description
# 3240  4018         LPA  AK38|APOA|LP  lipoprotein(a)
# 4018
#           id gene_symbol          synonyms                        description
# 15236  80781     COL18A1  GLCC|KNO|KNO1|KS  collagen type XVIII alpha 1 chain
# 80781
#         id gene_symbol                synonyms        description
# 5076  6404      SELPLG  CD162|CLA|PSGL-1|PSGL1  selectin P ligand
# 6404
#         id gene_symbol             synonyms     description
# 1649  2056         EPO  DBAL|ECYT5|EP|MVCD2  erythropoietin
# 2056
#         id gene_symbol                                           synonyms  \
# 2431  2993        GYPA  CD235a|GPA|GPErik|GPSAT|HGpMiV|HGpMiXI|HGpSta(...
#
#                           description
# 2431  glycophorin A (MNS blood group)
# 2993
#         id gene_symbol                          synonyms  \
# 5709  7124         TNF  DIF|TNF-alpha|TNFA|TNFSF2|TNLG1F
#
#                 description
# 5709  tumor necrosis factor
# 7124
#         id gene_symbol              synonyms   description
# 1176  1448        CSN3  CNS10|CSN10|CSNK|KCA  casein kappa
# 1448
#        id gene_symbol                     synonyms  \
# 891  1082        CGB3  CGB|CGB5|CGB7|CGB8|LHB|hCGB
#
#                                description
# 891  chorionic gonadotropin subunit beta 3
# 1082
#         id gene_symbol                                           synonyms  \
# 3595  4582        MUC1  ADMCKD|ADMCKD1|ADTKD2|CA 15-3|CD227|Ca15-3|EMA...
#
#                            description
# 3595  mucin 1, cell surface associated
# 4582
#         id gene_symbol                      synonyms  description
# 5324  6693         SPN  CD43|GALGP|GPL115|LEU-22|LSN  sialophorin
# 6693
#         id gene_symbol        synonyms                            description
# 3596  4583        MUC2  MLP|MUC-2|SMUC  mucin 2, oligomeric mucus/gel-forming
# 4583
#         id gene_symbol                               synonyms  \
# 3169  3920       LAMP2  CD107b|DND|LAMP-2|LAMPB|LGP-96|LGP110
#
#                                   description
# 3169  lysosomal associated membrane protein 2
# 3920
#         id gene_symbol             synonyms  \
# 3167  3916       LAMP1  CD107a|LAMPA|LGP120
#
#                                   description
# 3167  lysosomal associated membrane protein 1
# 3916
#         id gene_symbol                                   synonyms  \
# 5652  7066        THPO  CAMT2|MGDF|MKCSF|ML|MPLLG|THC9|THCYT1|TPO
#
#          description
# 5652  thrombopoietin
# 7066
#         id gene_symbol              synonyms                       description
# 3598  4585        MUC4  ASGP|HSA276359|MUC-4  mucin 4, cell surface associated
# 4585
#        id gene_symbol                                    synonyms  \
# 890  1081         CGA  CG-ALPHA|FSHA|GPA1|GPHA1|GPHa|HCG|LHA|TSHA
#
#                                   description
# 890  glycoprotein hormones, alpha polypeptide
# 1081
#         id gene_symbol synonyms        description
# 3601  4589        MUC7      MG2  mucin 7, secreted
# 4589
# Empty DataFrame
# Columns: [id, gene_symbol, synonyms, description]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/stephanieolaiya/Documents/Imagineset2/database/ingest_genes.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/Users/stephanieolaiya/Documents/Imagineset2/database/ingest_genes.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a>         gene_db_row = ingested_genes.loc[ingested_genes['gene_symbol'] == gene_symbol]
#      <a href='vscode-notebook-cell:/Users/stephanieolaiya/Documents/Imagineset2/database/ingest_genes.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a>         print(gene_db_row)
# ---> <a href='vscode-notebook-cell:/Users/stephanieolaiya/Documents/Imagineset2/database/ingest_genes.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a>         print(gene_db_row['id'].values[0])
#      <a href='vscode-notebook-cell:/Users/stephanieolaiya/Documents/Imagineset2/database/ingest_genes.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a>     # print(geneset_name)
#      <a href='vscode-notebook-cell:/Users/stephanieolaiya/Documents/Imagineset2/database/ingest_genes.ipynb#W6sZmlsZQ%3D%3D?line=18'>19</a>     # print(genes)
#      <a href='vscode-notebook-cell:/Users/stephanieolaiya/Documents/Imagineset2/database/ingest_genes.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a> break
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# write relation :                       
# gene__gene_set.writerow(dict(
#                         A=gene_id,
#                         B=gene_set_id,
#                       ))
